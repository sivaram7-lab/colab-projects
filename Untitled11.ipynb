# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaram7-lab/colab-projects/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install speechrecognition pydub

# %%
import speech_recognition as st
from pydub import AudioSegment
mp3_file='/content/calculator voice.mp3'
wav_file='/content/calculator voice.wav'
audio=AudioSegment.from_mp3(mp3_file)
audio.export("audio.wav",format="wav")
# Out:
# <_io.BufferedRandom name='audio.wav'>

# %%
import speech_recognition as sr
eco=sr.Recognizer()
with sr.AudioFile('/content/audio.wav') as source:
  audio_data=eco.record(source)
  text= eco.recognize_google(audio_data)
  print('transcript:',text)
# Out:
# transcript: 123 + 56

# %%
t=eval(text)
t
# Out:
# 179

# %%
res= "The result of "+ text + " is " + str(eval(text))
res
# Out:
# 'The result of 123 + 56 is 179'

# %%
# !pip install gTTS

# %%
from gtts import gTTS

# %%
b=gTTS(res)
b.save("add.mp3")

# %%
from IPython.display import Audio
Audio("/content/add.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
